# %% [markdown]
# Commande pour de soumission sur le leaderbord.
#
# Pensez à changer le message et le fichier (../submission.csv) <i>
#
# Si la commande ne fonctionne pas, c'est sûrement un problème de token, pour cela :
# * dans les paramètre du profil Kaggle (https://www.kaggle.com/settings), créer une Legacy API Key
# * déplacer le fichier JSON téléchargé dans un dossier .kaggle (à créer) de la racine
#  </i>

# %%
import pandas as pd
df = pd.read_csv('../submission.csv')
df['label'] = 8

# %%
# %%bash
# kaggle competitions submit -c reconnaissance-dabeilles-francaises -f ../submission.csv  -m "Nouvelle soumission"
# Out:
# 100%|██████████| 12.6k/12.6k [00:00<00:00, 31.6kB/s]
# Successfully submitted to Reconnaissance d'abeilles françaises
